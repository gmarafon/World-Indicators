# %%
import wbgapi as wb
import pandas as pd
import numpy as np
from pathlib import Path

# %%
Path.cwd()
# Out:
# WindowsPath('c:/Users/gfmar/OneDrive/Projects/World Indicators/notebooks')

# %%
wb.source.info()
# Out:
# id    name                                                                  code      concepts  lastupdated
# ----  --------------------------------------------------------------------  ------  ----------  -------------
# 1     Doing Business                                                        DBS              3  2021-08-18
# 2     World Development Indicators                                          WDI              3  2024-12-16
# 3     Worldwide Governance Indicators                                       WGI              3  2024-11-05
# 5     Subnational Malnutrition Database                                     SNM              3  2016-03-21
# 6     International Debt Statistics                                         IDS              4  2024-12-03
# 11    Africa Development Indicators                                         ADI              3  2013-02-22
# 12    Education Statistics                                                  EDS              3  2024-06-25
# ...

# %%
wb.series.info('AG.CON.FERT.PT.ZS')
# Out:
# id                 value
# -----------------  ---------------------------------------------------
# AG.CON.FERT.PT.ZS  Fertilizer consumption (% of fertilizer production)
#                    1 elements

# %%
series = wb.series.info(db=2)

# %%
series_dict = vars(series)
df_series = pd.DataFrame.from_dict(series_dict.get('items'))
list = df_series['id'].tolist()
list
# Out:
# ['AG.CON.FERT.PT.ZS',
#  'AG.CON.FERT.ZS',
#  'AG.LND.AGRI.K2',
#  'AG.LND.AGRI.ZS',
#  'AG.LND.ARBL.HA',
#  'AG.LND.ARBL.HA.PC',
#  'AG.LND.ARBL.ZS',
#  'AG.LND.CREL.HA',
#  'AG.LND.CROP.ZS',
#  'AG.LND.EL5M.RU.K2',
#  'AG.LND.EL5M.RU.ZS',
#  'AG.LND.EL5M.UR.K2',
#  'AG.LND.EL5M.UR.ZS',
#  'AG.LND.EL5M.ZS',
#  'AG.LND.FRST.K2',
#  'AG.LND.FRST.ZS',
#  'AG.LND.IRIG.AG.ZS',
#  'AG.LND.PRCP.MM',
#  'AG.LND.TOTL.K2',
#  'AG.LND.TOTL.RU.K2',
#  'AG.LND.TOTL.UR.K2',
#  'AG.PRD.CREL.MT',
#  'AG.PRD.CROP.XD',
#  'AG.PRD.FOOD.XD',
#  'AG.PRD.LVSK.XD',
#  'AG.SRF.TOTL.K2',
#  'AG.YLD.CREL.KG',
#  'BG.GSR.NFSV.GD.ZS',
#  'BM.GSR.CMCP.ZS',
#  'BM.GSR.FCTY.CD',
#  'BM.GSR.GNFS.CD',
#  'BM.GSR.INSF.ZS',
#  'BM.GSR.MRCH.CD',
#  'BM.GSR.NFSV.CD',
#  'BM.GSR.ROYL.CD',
#  'BM.GSR.TOTL.CD',
#  'BM.GSR.TRAN.ZS',
#  'BM.GSR.TRVL.ZS',
#  'BM.KLT.DINV.CD.WD',
#  'BM.KLT.DINV.WD.GD.ZS',
#  'BM.TRF.PRVT.CD',
#  'BM.TRF.PWKR.CD.DT',
#  'BN.CAB.XOKA.CD',
#  'BN.CAB.XOKA.GD.ZS',
#  'BN.FIN.TOTL.CD',
# ...

# %%
df_indicators = wb.data.DataFrame(['FR.INR.RINR', 'VC.IDP.NWDS'], time=range(2010, 2025), labels=True)

# %%
df_indicators.head(5)
# Out:
#                                    Country                  Series    YR2010  \
# economy series
# ZWE     FR.INR.RINR               Zimbabwe  Real interest rate (%)       NaN
# ZMB     FR.INR.RINR                 Zambia  Real interest rate (%)  6.112942
# YEM     FR.INR.RINR            Yemen, Rep.  Real interest rate (%)  0.175577
# PSE     FR.INR.RINR     West Bank and Gaza  Real interest rate (%) -6.062535
# VIR     FR.INR.RINR  Virgin Islands (U.S.)  Real interest rate (%)       NaN
#
#                        YR2011     YR2012     YR2013    YR2014     YR2015  \
# economy series
# ZWE     FR.INR.RINR       NaN   6.428554   1.525435  8.787605   8.144427
# ZMB     FR.INR.RINR  6.956560   4.821477  -0.191430  5.816368   6.179216
# YEM     FR.INR.RINR  5.830260  17.571334  11.788755       NaN        NaN
# PSE     FR.INR.RINR  1.296514   3.986037   1.681033  2.639404  10.892923
# VIR     FR.INR.RINR       NaN        NaN        NaN       NaN        NaN
#
# ...

# %%
df_indicators.reset_index(inplace=True)

# %%
df_indicators.rename(columns={'series' : 'Series ID', 'economy' : 'Economy'}, inplace=True)
# Out:
#     Economy    Series ID                         Country  \
# 0       ZWE  FR.INR.RINR                        Zimbabwe
# 1       ZMB  FR.INR.RINR                          Zambia
# 2       YEM  FR.INR.RINR                     Yemen, Rep.
# 3       PSE  FR.INR.RINR              West Bank and Gaza
# 4       VIR  FR.INR.RINR           Virgin Islands (U.S.)
# ..      ...          ...                             ...
# 527     CEB  VC.IDP.NWDS  Central Europe and the Baltics
# 528     CSS  VC.IDP.NWDS          Caribbean small states
# 529     ARB  VC.IDP.NWDS                      Arab World
# 530     AFW  VC.IDP.NWDS      Africa Western and Central
# 531     AFE  VC.IDP.NWDS     Africa Eastern and Southern
#
#                                                 Series        YR2010  \
# 0                               Real interest rate (%)           NaN
# 1                               Real interest rate (%)  6.112942e+00
# 2                               Real interest rate (%)  1.755766e-01
# ...
